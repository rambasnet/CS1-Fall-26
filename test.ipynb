// %%
#include <iostream>
#include <print>
using namespace std;

// %%
cout << "Hello World" << endl;
// Out:
// Hello World

// %%
print("Hello World!\n");
// Out:
// Hello World!

// %%
auto name = "John Smith";

// %%
print(name);
// Out:
// John Smith
